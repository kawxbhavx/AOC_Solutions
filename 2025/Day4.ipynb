# %%
#Part1
input = """..@@.@@@@.
@@@.@.@.@@
@@@@@.@.@@
@.@@@@..@.
@@.@@@@.@@
.@@@@@@@.@
.@.@.@.@@@
@.@@@.@@@@
.@@@@@@@@.
@.@.@@@.@."""
expected_result_pattern="""..xx.xx@x.
x@@.@.@.@@
@@@@@.x.@@
@.@@@@..@.
x@.@@@@.@x
.@@@@@@@.@
.@.@.@.@@@
x.@@@.@@@@
.@@@@@@@@.
x.x.@@@.x."""
expected_result_count=13


with open("input.txt", 'r', encoding='utf-8') as file:
  input = file.read()[:-1]

rows=input.split("\n")

padded_rows=[]
padded_rows.append("." + "." *len(rows[0]) + ".")
for row in rows:
  padded_rows.append("." + row + ".")
padded_rows.append("." + "." *len(rows[0]) + ".")

# for row in padded_rows:
#   print(row)

counts=0
result_pattern=[]
for r_idx in range(1,len(padded_rows)-1):
  result_row=""
  for c_idx in range(1,len(padded_rows[0])-1):
    if padded_rows[r_idx][c_idx]=="@":
      adj_count=0
      for r_adj in range(r_idx-1,r_idx+2):
        for c_adj in range(c_idx-1,c_idx+2):
          if padded_rows[r_adj][c_adj]=="@":
            adj_count+=1
      if adj_count<=4:
        counts+=1
        result_row=result_row+"x"
      else:
        result_row=result_row + padded_rows[r_idx][c_idx]
    else:
      result_row=result_row + padded_rows[r_idx][c_idx]
  result_pattern.append(result_row)
  #print(result_row)
print(counts)
# Out:
# 1540

# %%
#Part2
input = """..@@.@@@@.
@@@.@.@.@@
@@@@@.@.@@
@.@@@@..@.
@@.@@@@.@@
.@@@@@@@.@
.@.@.@.@@@
@.@@@.@@@@
.@@@@@@@@.
@.@.@@@.@."""
expected_result_pattern_2="""..xx.xx@x.
x@@.@.@.@@
@@@@@.x.@@
@.@@@@..@.
x@.@@@@.@x
.@@@@@@@.@
.@.@.@.@@@
x.@@@.@@@@
.@@@@@@@@.
x.x.@@@.x."""
expected_result_pattern_3=""".......x..
.@@.x.x.@x
x@@@@...@@
x.@@@@..x.
.@.@@@@.x.
.x@@@@@@.x
.x.@.@.@@@
..@@@.@@@@
.x@@@@@@@.
....@@@..."""
expected_result_pattern_final="""..........
..........
..........
...x@@....
...@@@@...
...@@@@@..
...@.@.@@.
...@@.@@@.
...@@@@@..
....@@@..."""
expected_result_count=43


with open("input.txt", 'r', encoding='utf-8') as file:
  input = file.read()[:-1]

def process_input(input):
  rows=input.split("\n")

  padded_rows=[]
  padded_rows.append("." + "." *len(rows[0]) + ".")
  for row in rows:
    padded_rows.append("." + row + ".")
  padded_rows.append("." + "." *len(rows[0]) + ".")

  # for row in padded_rows:
  #   print(row)

  counts=0
  result_pattern=[]
  for r_idx in range(1,len(padded_rows)-1):
    result_row=""
    for c_idx in range(1,len(padded_rows[0])-1):
      if padded_rows[r_idx][c_idx]=="@":
        adj_count=0
        for r_adj in range(r_idx-1,r_idx+2):
          for c_adj in range(c_idx-1,c_idx+2):
            if padded_rows[r_adj][c_adj]=="@":
              adj_count+=1
        if adj_count<=4:
          counts+=1
          result_row=result_row+"x"
        else:
          result_row=result_row + padded_rows[r_idx][c_idx]
      else:
        result_row=result_row + padded_rows[r_idx][c_idx]
    result_pattern.append(result_row)
    # print(result_row)
  # print(counts)
  return counts, result_pattern

iter=1
# print(f"iter{iter}")
final_counts=0
iter_counts, iter_pattern = process_input(input)
# print(iter_counts)
final_counts+=iter_counts
iter_pattern="\n".join(iter_pattern)
while "x" in iter_pattern:
  iter+=1
  # print(f"iter{iter}")
  input = iter_pattern.replace("x",".")
  iter_counts, iter_pattern = process_input(input)
  iter_pattern="\n".join(iter_pattern)
  # print(iter_counts)
  final_counts+=iter_counts
print(final_counts)
# Out:
# 8972
